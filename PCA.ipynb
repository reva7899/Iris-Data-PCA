# %% [markdown]
# <a href="https://colab.research.google.com/github/reva7899/Iris-Data-PCA/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from google.colab import drive
drive.mount('/content/gdrive')

# Separate the features and the labels
X = iris_df.iloc[:, :-1]
y = iris_df.iloc[:, -1]

# Convert the class labels to numeric values
le = LabelEncoder()
y = le.fit_transform(y)

# Create a 2D scatter plot matrix of each pair of the four components
pd.plotting.scatter_matrix(X, c=y, figsize=(10, 10))

# Create a 3D scatter plot of the first three components
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X.iloc[:, 0], X.iloc[:, 1], X.iloc[:, 2], c=y)
ax.set_xlabel('Sepal length')
ax.set_ylabel('Sepal width')
ax.set_zlabel('Petal length')
plt.show()

# Perform PCA on the dataset and extract the explained variance ratio
pca = PCA(n_components=4)
pca.fit(X)
variance_ratio = pca.explained_variance_ratio_

# Plot the explained variance ratio in a bar plot
fig, ax = plt.subplots()
ax.bar(range(1, len(variance_ratio)+1), variance_ratio)
ax.set_xlabel('Principal Component')
ax.set_ylabel('Variance Ratio')
plt.show()

# Calculate the correlation matrix of the four components
corr_matrix = X.corr()

# Calculate the covariance matrix of the four components
cov_matrix = X.cov()
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
